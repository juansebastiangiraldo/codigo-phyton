# %%
def sumar (a,b):
  resultado = a + b
  return resultado

# %%
sumar(2,6)
# Out:
# 8

# %%
def es_par_impar(numero):
  if numero % 2 == 0:
       return "El numero es par"
  else:
       return "El numero es impar"

# %%
print(es_par_impar(5))
# Out:
# El numero es impar

# %%
def saludar(nombre):
  return f"Hola {nombre}¡"

# %%
print(saludar("Juan"))
# Out:
# Hola Juan
# None

# %%
import math
def area_circulo(radio):
  area = math.pi * radio ** 2
  return area

# %%
print(area_circulo(10))
# Out:
# 314.1592653589793

# %%
def determinar_num(numero):
  if numero > 0:
    return "el numero es positivo"
  elif numero < 0:
    return "el numero es negativo"
  elif numero == 0:
    return "el numero es 0"

# %%
print(determinar_num(-2))
# Out:
# el numero es negativo

# %%
def celcius_a_fahrenheit(celcius):
  return(celcius * 9/5) + 32

# %%
print(celcius_a_fahrenheit(90))
# Out:
# 194.0

# %%
def numero_cuadrado(numero):
  return numero * numero

# %%
print(numero_cuadrado(8))
# Out:
# 64

# %%
def factorial(numero):
  if numero == 0:
    return 1
  else:
    return numero * factorial(numero - 1)

# %%
print(factorial(6))
# Out:
# 720

# %%
def vocales_palabra(palabras):
  vocales = "aeiouAEIOU"
  contador = 0
  for letra in palabras:
    if letra in vocales:
      contador += 1
  return contador

# %%
print(vocales_palabra("hola wordl"))
# Out:
# 3

# %%
def tabla_multiplicar(numero):
  for n in range(1, 11):
   print(f"{numero} * {n} = {numero * n}")

# %%
print(tabla_multiplicar(7))
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
# None

# %%
import math
def area_circulo(radio):
  area = math.pi * radio ** 2
  return area
def area_triangulo(base, altura):
  area = (base * altura) / 2
  return area
def area_rectangulo(base, altura):
  area = base * altura
  return area
def menu():
  print("Calculo de areas")
  print("1- Circulo")
  print("2- Triangulo")
  print("3- Rectangulo")

Option = input("seleccionar una opciion del (1-3): ")
if Option == "1":
  radio = float(input("Ingrese el radio del circulo: "))
  print(f"El area del circulo es: {area_circulo(radio): .2f}")
elif Option == "2":
  base = float(input("Ingrese la base del triangulo: "))
  altura = float(input("Ingrese la altura del triangulo: "))
  print(f"El area del triangulo es: {area_triangulo(base, altura): .2f}")
elif Option == "3":
  base = float(input("Ingrese la base del rectangulo: "))
  altura = float(input("Ingrese la altura del rectangulo: "))
  print(f"El area del rectangulo es: {area_rectangulo(base, altura): .2f}")
else:
  print("Opcion no valida, escoja una opcion correcta")
# Out:
# seleccionar una opciion del (1-3): 2
# Ingrese la base del triangulo: 30
# Ingrese la altura del triangulo: 15
# El area del triangulo es:  225.00
